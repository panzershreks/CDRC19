# %%
import pandas as pd

owid = pd.read_csv('owid-covid-data.csv')
owid
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 125097      ZWE    Africa     Zimbabwe  2021-10-16     132333.0       48.0
# 125098      ZWE    Africa     Zimbabwe  2021-10-17     132368.0       35.0
# 125099      ZWE    Africa     Zimbabwe  2021-10-18     132368.0        0.0
# 125100      ZWE    Africa     Zimbabwe  2021-10-19     132405.0       37.0
# 125101      ZWE    Africa     Zimbabwe  2021-10-20     132437.0       32.0
#
# ...

# %%
owid = owid.sort_values('date').drop_duplicates('iso_code',keep='last')

# %%
owid = owid.sort_values('iso_code')
owid.to_csv('owid_latest.csv', encoding='utf-8')
